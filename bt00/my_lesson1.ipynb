# %% [markdown]
# # Bắt đầu

# %% [markdown]
# ## Bài tập 1: Chạy bài tập python tính toán đơn giản ở file ex1_calc.py

# %%
# %run ex1_calc.py
# Out:
# calculator basic
# tổng a và b là c = 12 + 24 = 36
